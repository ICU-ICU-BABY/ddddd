# %%
# The start of the journey
print('Hello World. Sup. How are yall doing')
# Trying task 1
print('Hellow World!!!!', 'I am iron man', 'No, I am Tony Stark', 'No, I am Poppy')
# That does all strings in one line
# Let's try again
print('''Hellow World!!!!
I am iron man
No, I am Tony Stark
No, I am Poppy''')
# Imagine having to do the above code for 100 or 1000 items
# Let's try again
# Out:
# Hello World. Sup. How are yall doing
# Hellow World!!!! I am iron man No, I am Tony Stark No, I am Poppy
# Hellow World!!!!
# I am iron man
# No, I am Tony Stark
# No, I am Poppy

# %%
# Let's try here for some clarity
print('Hellow World!!!!' + 'I am iron man' + 'No, I am Tony Stark' + 'No, I am Poppy')
# Haha, no spaces
#Let's try again
print('Hello World!!!! ' + 'I am iron man' + ' No, I am Tony Stark' + ' No, I am Poppy')
# This is still all one line so let's try another method
print('Hellow World!!!! \n' + 'I am iron man \n' + 'No, I am Tony Stark \n' + 'No, I am Poppy')
#
# The Backslash n is the indiactor for New line: "New line indicator character"
#
# Let's try to multiply
print("I am Poppy\n" * 100)
# Out:
# Hellow World!!!!I am iron manNo, I am Tony StarkNo, I am Poppy
# Hello World!!!! I am iron man No, I am Tony Stark No, I am Poppy
# Hellow World!!!!
# I am iron man
# No, I am Tony Stark
# No, I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# I am Poppy
# ...
